# %% [markdown]
# Week 1 Section 1 Exercise Set 1

# %%
import pandas as pd

data = {
"Name": [
    "Alice", "Bob", "Charlie", "David", "Evelyn",
    "Frank", "Grace", "Henry", "Isla", "Jack",
    "Karen", "Leo", "Mia", "Noah", "Olivia",
    "Paul", "Quinn", "Ruby", "Sam", "Tina"
],
"Age": [25, 32, 37, 29, 41, 28, 34, 45, 26, 31, 39, 27, 33, 36, 30, 42, 24, 38, 35, 29],
"Department": [
    "HR", "Engineering", "Sales", "Marketing", "Engineering",
    "Finance", "Support", "Operations", "HR", "Sales",
    "Engineering", "Support", "Marketing", "Finance", "Operations",
    "Engineering", "HR", "Sales", "Support", "Marketing"
],
"Salary": [
    50000, 75000, 62000, 58000, 80000,
    54000, 52000, 70000, 51000, 64000,
    82000, 53000, 60000, 56000, 68000,
    79000, 49500, 65500, 54500, 61000
],
}

df = pd.DataFrame(data)

# %%
df.head(5)
# Out:
#       Name  Age   Department  Salary
# 0    Alice   25           HR   50000
# 1      Bob   32  Engineering   75000
# 2  Charlie   37        Sales   62000
# 3    David   29    Marketing   58000
# 4   Evelyn   41  Engineering   80000

# %%
df.tail(5)
# Out:
#      Name  Age   Department  Salary
# 15   Paul   42  Engineering   79000
# 16  Quinn   24           HR   49500
# 17   Ruby   38        Sales   65500
# 18    Sam   35      Support   54500
# 19   Tina   29    Marketing   61000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        20 non-null     str
#  1   Age         20 non-null     int64
#  2   Department  20 non-null     str
#  3   Salary      20 non-null     int64
# dtypes: int64(2), str(2)
# memory usage: 772.0 bytes

# %%
print(df.shape)
# Out:
# (20, 4)

# %% [markdown]
# Week 1 Exercise Set 2

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.loc[12, ['Name', 'Age']])
# Out:
# Name    Saundercock, Mr. William Henry
# Age                               20.0
# Name: 12, dtype: object

# %%
df.iloc[:5, :3]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
df.loc[(df['Pclass'] == 1) & (df['Sex'] == 'female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 3        0    113803   53.1000  C123        S
# 11       0    113783   26.5500  C103        S
# 31       0  PC 17569  146.5208   B78        C
# 52       0  PC 17572   76.7292   D33        C
# ..     ...       ...       ...   ...      ...
# 856      1     36928  164.8667   NaN        S
# 862      0     17466   25.9292   D17        S
# 871      1     11751   52.5542   D35        S
# 879      1     11767   83.1583   C50        C
# 887      0    112053   30.0000   B42        S
#
# [94 rows x 12 columns]

# %%
df.iloc[9]['Age']
# Out:
# np.float64(14.0)

# %%
df.loc[100:105, ['Fare', 'Survived']]
# Out:
#         Fare  Survived
# 100   7.8958         0
# 101   7.8958         0
# 102  77.2875         0
# 103   8.6542         0
# 104   7.9250         0
# 105   7.8958         0

# %% [markdown]
# Week 1 Exercise Set 3

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Fare'].max()
# Out:
# np.float64(512.3292)

# %%
df['Name'].nunique()
# Out:
# 891

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# Week 1 Section 2 Exercise Set 1

# %%
import pandas as pd

data = {
"Name": ["Alice", "Bob", "Charlie", "David"],
"Age": [25, 30, 35, 40],
"City": ["NYC", "LA", "Chicago", "Miami"],
"Email": ["a@example.com", "b@example.com", "c@example.com", "d@example.com"],
}

df = pd.DataFrame(data)

# %%
df_no_email = df.drop(columns=['Email'])
print(df_no_email)
# Out:
#       Name  Age     City
# 0    Alice   25      NYC
# 1      Bob   30       LA
# 2  Charlie   35  Chicago
# 3    David   40    Miami

# %%
df.drop(index=2, inplace=True)
print(df)
# Out:
#     Name  Age   City          Email
# 0  Alice   25    NYC  a@example.com
# 1    Bob   30     LA  b@example.com
# 3  David   40  Miami  d@example.com

# %%
df = df.drop(columns=['City', 'Email'])
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 3  David   40

# %%
df_trimmed = df.drop(index=[0, len(df)-1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df_trimmed = df.drop(index=[0, len(df)-1])
#
# File c:\Users\Code\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
#    6296     )
#
# File c:\Users\Code\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4642 for axis, labels in axes.items():
#    4643     if labels is not None:
# -> 4644         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4646 if inplace:
#    4647     self._update_inplace(obj)
#
# File c:\Users\Code\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4684         new_axis = axis.drop(labels, level=level, errors=errors)
#    4685     else:
# -> 4686         new_axis = axis.drop(labels, errors=errors)
#    4687     indexer = axis.get_indexer(new_axis)
#    4689 # Case for non-unique axis
#    4690 else:
#
# File c:\Users\Code\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: '[2] not found in axis'

# %% [markdown]
# Week 1 Section 2 Exercise Set 2

# %%
import pandas as pd
import numpy as np

data = {
"Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
"Age": [25, np.nan, 35, 40, None],
"City": ["NYC", "LA", None, "Miami", "Boston"],
}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#       Name   Age    City
# 0    Alice  25.0     NYC
# 1      Bob   NaN      LA
# 2  Charlie  35.0     NaN
# 3    David  40.0   Miami
# 4      Eva   NaN  Boston

# %%
df.isnull()
# Out:
#     Name    Age   City
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False  False  False
# 4  False   True  False

# %%
df.isnull().sum()
# Out:
# Name    0
# Age     2
# City    1
# dtype: int64

# %%
df = df.dropna()
print(df)
# Out:
#     Name   Age   City
# 0  Alice  25.0    NYC
# 3  David  40.0  Miami

# %%
df = df.dropna(axis=1)
print(df)
# Out:
#     Name   Age   City
# 0  Alice  25.0    NYC
# 3  David  40.0  Miami

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['City'] = df['City'].fillna("Unknown")

# %% [markdown]
# Week 1 Section 2 Exercise Set 3

# %%
import pandas as pd

data = {
"Name": ["Alice", "Bob", "Charlie", "Alice", "Bob", "Diana"],
"Age": [25, 30, 35, 25, 30, 40],
"City": ["NYC", "LA", "SF", "NYC", "LA", "NYC"],
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age City
# 0    Alice   25  NYC
# 1      Bob   30   LA
# 2  Charlie   35   SF
# 3    Alice   25  NYC
# 4      Bob   30   LA
# 5    Diana   40  NYC

# %%
df[df.duplicated()]
# Out:
#     Name  Age City
# 3  Alice   25  NYC
# 4    Bob   30   LA

# %%
df = df.drop_duplicates()
print(df)
# Out:
#       Name  Age City
# 0    Alice   25  NYC
# 1      Bob   30   LA
# 2  Charlie   35   SF
# 5    Diana   40  NYC

# %%
df = df.drop_duplicates(keep='last')
print(df)

# %%
df = df.drop_duplicates(keep=False)

# %% [markdown]
# Week 1 Section 3 Exercise Set 1

# %%
import pandas as pd

data = {
"fname": ["Alice", "Bob", "Charlie"],
"lname": ["Smith", "Jones", "Brown"],
"ctry": ["USA", "Canada", "UK"],
}

df = pd.DataFrame(data)

# %%
df = df.rename(columns={'fname': 'FirstName', 'lname': 'LastName'})
print(df)
# Out:
#   FirstName LastName    ctry
# 0     Alice    Smith     USA
# 1       Bob    Jones  Canada
# 2   Charlie    Brown      UK

# %%
df.columns = ['FirstName', 'LastName', 'Country']
print(df)
# Out:
#   FirstName LastName Country
# 0     Alice    Smith     USA
# 1       Bob    Jones  Canada
# 2   Charlie    Brown      UK

# %% [markdown]
# Week 1 Section 3 Exercise Set 2

# %%
import pandas as pd

data = {
"Name": ["Alice", "Bob", "Charlie"],
"Dept": ["HR", "Finance", "IT"],
"Sal": [60000, 70000, 80000],
}

df = pd.DataFrame(data)

# %%
df = df.rename(columns={'Dept': 'Department', 'Sal': 'Salary'})
print(df)
# Out:
#       Name Department  Salary
# 0    Alice         HR   60000
# 1      Bob    Finance   70000
# 2  Charlie         IT   80000

# %%
df = df[['Salary', 'Name', 'Department']]
print(df)
# Out:
#    Salary     Name Department
# 0   60000    Alice         HR
# 1   70000      Bob    Finance
# 2   80000  Charlie         IT

# %%
print(df)
# Out:
#    Salary     Name Department
# 0   60000    Alice         HR
# 1   70000      Bob    Finance
# 2   80000  Charlie         IT

# %% [markdown]
# Week 1 Section 3 Exercise Set 3

# %%
import pandas as pd

data = {
"Store": ["A", "A", "A", "B", "B", "C", "C", "C", "C"],
"Product": ["Apples", "Oranges", "Bananas", "Apples", "Bananas", "Oranges", "Apples", "Bananas", "Bananas"],
"Sales": [100, 80, 90, 120, 110, 60, 95, 85, 75],
"Profit": [30, 25, 20, 40, 35, 15, 32, 22, 18],
}

df = pd.DataFrame(data)
print(df.head())
# Out:
#   Store  Product  Sales  Profit
# 0     A   Apples    100      30
# 1     A  Oranges     80      25
# 2     A  Bananas     90      20
# 3     B   Apples    120      40
# 4     B  Bananas    110      35

# %%
df.groupby('Store')[['Sales', 'Profit']].mean()
# Out:
#         Sales  Profit
# Store
# A       90.00   25.00
# B      115.00   37.50
# C       78.75   21.75

# %%
df.groupby('Product').agg(
    Max_Sales=('Sales', 'max'),
    Min_Profit=('Profit', 'min')
)
# Out:
#          Max_Sales  Min_Profit
# Product
# Apples         120          30
# Bananas        110          18
# Oranges         80          15

# %%
df.groupby('Store').agg(
    Avg_Sales=('Sales', 'mean'),
    Max_Profit=('Profit', 'max')
)
# Out:
#        Avg_Sales  Max_Profit
# Store
# A          90.00          30
# B         115.00          40
# C          78.75          32

# %%
df.groupby(['Store', 'Product']).agg(
    Total_Sales=('Sales', 'sum')
)
# Out:
#                Total_Sales
# Store Product
# A     Apples           100
#       Bananas           90
#       Oranges           80
# B     Apples           120
#       Bananas          110
# C     Apples            95
#       Bananas          160
#       Oranges           60

# %% [markdown]
# Week 1 Section 3 Exercise Set 4

# %%
import pandas as pd

df_customers = pd.DataFrame({
"CustomerName": ["Alice", "Bob", "Charlie"]
}, index=[101, 102, 103])

df_orders = pd.DataFrame({
"OrderTotal": [250, 300, 400]
}, index=[101, 102, 103])

df_cities = pd.DataFrame({
    "City": ["NYC", "LA", "Chicago"]
}, index=[101, 102, 103])

# %%
df_customers.join(df_orders)
# Out:
#     CustomerName  OrderTotal
# 101        Alice         250
# 102          Bob         300
# 103      Charlie         400

# %%
df_customers["City"] = df_cities["City"]
